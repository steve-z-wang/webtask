# %% [markdown]
# # Computer Use Demo (Visual Mode)
#
# This notebook demonstrates using webtask in **visual mode** with Google's Computer Use model.
#
# In visual mode:
# - Agent sees screenshots (no DOM tree)
# - Agent uses pixel-based tools (click_at, type_text_at, scroll_at, etc.)
# - Coordinates are normalized (0-999) and scaled to actual viewport

# %%
from webtask import Webtask
from webtask.integrations.llm.google import GeminiComputerUse
# Out:
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'value'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'value'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'text'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'text'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'file_indexes'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'element_id'
# <module>:2: No type or annotation for parameter 'file_indexes'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'text'
# <module>:4: No type or annotation for parameter 'description'
# <module>:5: No type or annotation for parameter 'press_enter'
# <module>:6: No type or annotation for parameter 'clear_before_typing'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'text'
# <module>:4: No type or annotation for parameter 'description'
# <module>:5: No type or annotation for parameter 'press_enter'
# <module>:6: No type or annotation for parameter 'clear_before_typing'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'direction'
# <module>:4: No type or annotation for parameter 'description'
# <module>:5: No type or annotation for parameter 'magnitude'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'direction'
# <module>:4: No type or annotation for parameter 'description'
# <module>:5: No type or annotation for parameter 'magnitude'
# <module>:1: No type or annotation for parameter 'direction'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'direction'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'dest_x'
# <module>:4: No type or annotation for parameter 'dest_y'
# <module>:5: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'x'
# <module>:2: No type or annotation for parameter 'y'
# <module>:3: No type or annotation for parameter 'dest_x'
# <module>:4: No type or annotation for parameter 'dest_y'
# <module>:5: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'url'
# <module>:1: No type or annotation for parameter 'url'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'keys'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'keys'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'tab_index'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'tab_index'
# <module>:2: No type or annotation for parameter 'description'
# <module>:1: No type or annotation for parameter 'seconds'
# <module>:1: No type or annotation for parameter 'seconds'

# %% [markdown]
# ## Setup
#
# Create a Webtask instance and GeminiComputerUse LLM.
#
# The `GeminiComputerUse` class:
# - Uses the `gemini-2.5-computer-use-preview-05-2025` model
# - Has `coordinate_scale = 1000` (model returns 0-999 coordinates)

# %%
wt = Webtask()
llm = GeminiComputerUse()

# %% [markdown]
# ## Create Agent in Visual Mode
#
# Set `mode="visual"` to use pixel-based tools and screenshot context.
# Browser options like `headless` are passed to `create_agent()`.

# %%
agent = await wt.create_agent(llm=llm, mode="full", headless=False)

# %% [markdown]
# ## Run a Task
#
# The agent will:
# 1. See screenshots of the page
# 2. Use tools like `click_at(x, y)` and `type_text_at(x, y, text)` to interact

# %%
result = await agent.do(
    "Go to https://practicesoftwaretesting.com/, search for 'Cordless Drill 24V', and add it to the cart"
)
print(f"Feedback: {result.feedback}")
# Out:
# Feedback: Searched for 'Cordless Drill 24V' and clicked 'Add to cart' on the product page.

# %% [markdown]
# ## Cleanup

# %%
await wt.close()
