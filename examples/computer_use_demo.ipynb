# %% [markdown]
# # Computer Use Demo (Visual Mode)
#
# This notebook demonstrates using webtask in **visual mode** with Google's Computer Use model.
#
# In visual mode:
# - Agent sees screenshots (no DOM tree)
# - Agent uses pixel-based tools (click_at, type_text_at, scroll_at, etc.)
# - Coordinates are normalized (0-999) and scaled to actual viewport

# %%
from webtask import Webtask
from webtask.integrations.llm.google import GeminiComputerUse

# %% [markdown]
# ## Setup
#
# Create a Webtask instance and GeminiComputerUse LLM.
#
# The `GeminiComputerUse` class:
# - Uses the `gemini-2.5-computer-use-preview-05-2025` model
# - Has `coordinate_scale = 1000` (model returns 0-999 coordinates)

# %%
wt = Webtask()
llm = GeminiComputerUse()

# %% [markdown]
# ## Create Agent in Visual Mode
#
# Set `mode="visual"` to use pixel-based tools and screenshot context.
# Browser options like `headless` are passed to `create_agent()`.

# %%
agent = await wt.create_agent(llm=llm, mode="visual", headless=False)

# %% [markdown]
# ## Run a Task
#
# The agent will:
# 1. See screenshots of the page
# 2. Use tools like `click_at(x, y)` and `type_text_at(x, y, text)` to interact

# %%
result = await agent.do(
    "Go to https://practicesoftwaretesting.com/, search for 'Cordless Drill 24V', and add it to the cart"
)
print(f"Feedback: {result.feedback}")
# Out:
# Tools at indices [1] are not compatible with automatic function calling (AFC). AFC is disabled. If AFC is intended, please include python callables in the tool list, and do not include function declaration in the tool list.
# Tools at indices [1] are not compatible with automatic function calling (AFC). AFC is disabled. If AFC is intended, please include python callables in the tool list, and do not include function declaration in the tool list.
# Tools at indices [1] are not compatible with automatic function calling (AFC). AFC is disabled. If AFC is intended, please include python callables in the tool list, and do not include function declaration in the tool list.
# Tools at indices [1] are not compatible with automatic function calling (AFC). AFC is disabled. If AFC is intended, please include python callables in the tool list, and do not include function declaration in the tool list.
# Tools at indices [1] are not compatible with automatic function calling (AFC). AFC is disabled. If AFC is intended, please include python callables in the tool list, and do not include function declaration in the tool list.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = await agent.do(
#       2     "Go to https://practicesoftwaretesting.com/, search for 'Cordless Drill 24V', and add it to the cart"
#       3 )
#       4 print(f"Feedback: {result.feedback}")
#
# File ~/Github/web-auto/webtask/src/webtask/agent/agent.py:259, in Agent.do(self, task, max_steps, wait_after_action, files, output_schema, dom_mode)
#     233 async def do(
#     234     self,
#     235     task: str,
#    (...)    240     dom_mode: str = "accessibility",
#     241 ) -> Result:
#     242     """
#     243     Execute a task using TaskRunner.
#     244
#    (...)    257         TaskAbortedError: If task is aborted
#     258     """
# --> 259     run = await self._run_task(
#     260         task=task,
#     261         max_steps=max_steps,
#     262         wait_after_action=wait_after_action,
#     263         dom_mode=dom_mode,
#     264         output_schema=output_schema,
#     265         files=files,
#     266         exception_class=TaskAbortedError,
#     267     )
#     269     return Result(output=run.result.output, feedback=run.result.feedback)
#
# File ~/Github/web-auto/webtask/src/webtask/agent/agent.py:218, in Agent._run_task(self, task, max_steps, wait_after_action, dom_mode, output_schema, files, exception_class)
#     211 # Create TaskRunner for this run with tools and context callback
#     212 task_runner = TaskRunner(
#     213     llm=self.llm,
#     214     tools=tools,
#     215     get_context=get_context,
#     216 )
# --> 218 run = await task_runner.run(
#     219     task,
#     220     max_steps,
#     221     previous_runs=self._previous_runs if self.stateful else None,
#     222     output_schema=output_schema,
#     223 )
#     225 if self.stateful:
#     226     self._previous_runs.append(run)
#
# File ~/Github/web-auto/webtask/src/webtask/_internal/agent/task_runner.py:80, in TaskRunner.run(self, task, max_steps, previous_runs, output_schema)
#      77 all_messages = self._prepare_messages(session_start_messages, pairs)
#      79 self._logger.debug("Sending LLM request...")
# ---> 80 assistant_msg = await self._llm.call_tools(
#      81     messages=all_messages,
#      82     tools=tool_registry.get_all(),
#      83 )
#      85 reasoning = self._extract_reasoning(assistant_msg)
#      86 tool_names = (
#      87     [tc.name for tc in assistant_msg.tool_calls]
#      88     if assistant_msg.tool_calls
#      89     else []
#      90 )
#
# File ~/Github/web-auto/webtask/src/webtask/integrations/llm/google/gemini_computer_use.py:137, in GeminiComputerUse.call_tools(self, messages, tools)
#     130     self.logger.info(
#     131         f"Token usage - Prompt: {usage.prompt_token_count}, "
#     132         f"Response: {usage.candidates_token_count}, "
#     133         f"Total: {usage.total_token_count}"
#     134     )
#     136 # Parse response
# --> 137 assistant_msg = self._parse_response(response)
#     138 self._debugger.save_call(messages, assistant_msg)
#     139 return assistant_msg
#
# File ~/Github/web-auto/webtask/src/webtask/integrations/llm/google/gemini_computer_use.py:147, in GeminiComputerUse._parse_response(self, response)
#     144 content_parts = []
#     146 if response.candidates and response.candidates[0].content:
# --> 147     for part in response.candidates[0].content.parts:
#     148         # Check for text content
#     149         if hasattr(part, "text") and part.text:
#     150             content_parts.append(TextContent(text=part.text))
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ## Cleanup

# %%
await wt.close()
